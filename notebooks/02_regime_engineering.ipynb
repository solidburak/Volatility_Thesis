# %%
# 1. Imports
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src import data_loader, features, volatility, regimes, config

# 2. Standard Ingest and ML-Safe Features
raw_df = data_loader.fetch_raw_data()
stat_df = features.engineer_stationary_features(raw_df)

# Note: Dynamic Winsorization natively handles Black Swans now
garch_df = volatility.generate_expanding_garch(stat_df, window_size=252, refit_freq=21)

# 3. Generate Targets
smooth_df = regimes.generate_smoothed_targets(
    garch_df, lower_quant=0.85, upper_quant=0.95, window=252
)

# New: Industry-Standard Expanding HMM
# Using a 504-day (2 year) initial window to give the HMM plenty of history 
# before it starts making out-of-sample predictions.
hmm_df = regimes.generate_expanding_hmm_targets(
    garch_df, 
    feature_cols=['Log_Return', 'Vol_EGARCH'], 
    vol_col='Vol_EGARCH',
    n_components=3,
    min_window=504,
    refit_freq=21
)

# 4. Robust Concatenation via Inner Join
comparison_df = pd.concat([garch_df['Log_Return'], smooth_df, hmm_df], axis=1, join='inner')

# Print Final Distributions
print("="*50)
print("Target Class Distributions (Strictly Out-of-Sample)")
print("="*50)
print("\nMethod A: 10-day Smoothed Targets:")
print(comparison_df['Target_Smooth_10d'].value_counts().sort_index())

print("\nMethod B: Expanding 3-State HMM Targets:")
print(comparison_df['Target_HMM'].value_counts().sort_index())
# Out:
# 2026-06-04 10:52:44 - src.data_loader - INFO - Loading cached master raw data from /home/solidburak/Documents/Codes/Python/Thesis/data/raw/master_raw_data.parquet...
# 2026-06-04 10:52:44 - src.features - INFO - Engineering stationary features and applying macro lags...
# 2026-06-04 10:52:44 - src.features - INFO - Stationary transformation complete. Final shape: (6469, 8)
# 2026-06-04 10:52:44 - src.volatility - INFO - Generating Expanding GARCH & EGARCH (Window: 252, Refit: 21 days)...
# 2026-06-04 10:52:57 - src.volatility - INFO - Out-of-sample generation complete. Shape: (6217, 10)
# 2026-06-04 10:52:57 - src.regimes - INFO - Generating rolling heuristic regimes and smoothed targets...
# 2026-06-04 10:52:57 - src.regimes - INFO - Smoothed heuristic targets generated. Shape: (5965, 1)
# 2026-06-04 10:52:57 - src.regimes - INFO - Starting Expanding HMM (Min Window: 504, Refit: 21 days)...
# 2026-06-04 10:55:17 - src.regimes - INFO - Expanding HMM Target generation complete. Shape: (5713, 1)
# ==================================================
# Target Class Distributions (Strictly Out-of-Sample)
# ==================================================
#
# Method A: 10-day Smoothed Targets:
# Target_Smooth_10d
# 0    5245
# 1     106
# 2     362
# Name: count, dtype: int64
#
# Method B: Expanding 3-State HMM Targets:
# Target_HMM
# 0    3103
# 1    1724
# 2     886
# Name: count, dtype: int64

# %%
# ---------------------------------------------------------
# Plotting Function
# ---------------------------------------------------------
def plot_regime_comparison(df, title_suffix="XLK"):
    fig, axes = plt.subplots(2, 1, figsize=(16, 10), sharex=True)
    color_map = {1: ('orange', 0.3), 2: ('red', 0.5)}
    
    # TOP: Smoothed
    axes[0].plot(df.index, df['Log_Return'], color='black', linewidth=0.5)
    diff_smooth = df['Target_Smooth_10d'].diff().fillna(0)
    changes_smooth = df[diff_smooth != 0].index.tolist()
    changes_smooth.insert(0, df.index[0])
    changes_smooth.append(df.index[-1])
    
    for i in range(len(changes_smooth)-1):
        start, end = changes_smooth[i], changes_smooth[i+1]
        regime = df.loc[start, 'Target_Smooth_10d']
        if regime in color_map:
            color, alpha = color_map[regime]
            axes[0].axvspan(start, end, color=color, alpha=alpha)
            
    axes[0].set_title(f"Method A: Manual Rolling Thresholds ({title_suffix})", fontsize=14)
    axes[0].set_ylabel("Log Return")
    
    # BOTTOM: HMM
    axes[1].plot(df.index, df['Log_Return'], color='black', linewidth=0.5)
    diff_hmm = df['Target_HMM'].diff().fillna(0)
    changes_hmm = df[diff_hmm != 0].index.tolist()
    changes_hmm.insert(0, df.index[0])
    changes_hmm.append(df.index[-1])
    
    for i in range(len(changes_hmm)-1):
        start, end = changes_hmm[i], changes_hmm[i+1]
        regime = df.loc[start, 'Target_HMM']
        if regime in color_map:
            color, alpha = color_map[regime]
            axes[1].axvspan(start, end, color=color, alpha=alpha)
            
    axes[1].set_title(f"Method B: Expanding Hidden Markov Model ({title_suffix})", fontsize=14)
    axes[1].set_ylabel("Log Return")
    
    plt.tight_layout()
    plt.show()

plot_regime_comparison(comparison_df)

# %%
# ---------------------------------------------------------
# Testing the 4-State HMM Mapped to 3 Classes
# ---------------------------------------------------------
print("\n--- Generating 4-State HMM ---")
hmm_4_df = regimes.generate_expanding_hmm_targets(
    garch_df, 
    feature_cols=['Log_Return', 'Vol_EGARCH'], 
    vol_col='Vol_EGARCH',
    n_components=4,
    min_window=504,
    refit_freq=21
)

# Merge
comparison_4_df = pd.concat([garch_df['Log_Return'], smooth_df, hmm_4_df], axis=1, join='inner')

# Map the 4-state HMM down to 3 classes
# Because the src code guarantees State 0 is always lowest vol and State 3 is highest,
# this mapping is completely safe and won't be scrambled by label switching.
mapping_dict = {
    0: 0,  # Dead Calm -> Calm
    1: 0,  # Normal -> Calm
    2: 1,  # Elevated
    3: 2   # Shock
}

comparison_4_df['Target_HMM'] = comparison_4_df['Target_HMM'].map(mapping_dict)

print("\n" + "="*50)
print("FINAL MACHINE LEARNING TARGET DISTRIBUTION (4-State mapped to 3)")
print("="*50)
print(comparison_4_df['Target_HMM'].value_counts().sort_index())

plot_regime_comparison(comparison_4_df, title_suffix="XLK - 4-State Mapped to 3")
# Out:
# 2026-06-04 10:55:18 - src.regimes - INFO - Starting Expanding HMM (Min Window: 504, Refit: 21 days)...
# --- Generating 4-State HMM ---
# 2026-06-04 10:55:25 - hmmlearn.base - WARNING - Model is not converging.  Current: -501.1340436937427 is not greater than -501.1305586389185. Delta is -0.0034850548241820434
# 2026-06-04 10:55:26 - hmmlearn.base - WARNING - Model is not converging.  Current: -275.6650844259672 is not greater than -275.6628006902274. Delta is -0.0022837357398088898
# 2026-06-04 10:55:28 - hmmlearn.base - WARNING - Model is not converging.  Current: -199.42726472275257 is not greater than -199.30528253835325. Delta is -0.12198218439931452
# 2026-06-04 10:55:29 - hmmlearn.base - WARNING - Model is not converging.  Current: -211.40627121698955 is not greater than -211.35120456690106. Delta is -0.05506665008849154
# 2026-06-04 10:55:31 - hmmlearn.base - WARNING - Model is not converging.  Current: -229.96284013582402 is not greater than -229.9583398652935. Delta is -0.004500270530513717
# 2026-06-04 10:55:39 - hmmlearn.base - WARNING - Model is not converging.  Current: -474.61540773092713 is not greater than -474.6146418515895. Delta is -0.000765879337620845
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 # ---------------------------------------------------------
#       2 # Testing the 4-State HMM Mapped to 3 Classes
#       3 # ---------------------------------------------------------
#       4 print("\n--- Generating 4-State HMM ---")
# ----> 5 hmm_4_df = regimes.generate_expanding_hmm_targets(
#       6     garch_df,
#       7     feature_cols=['Log_Return', 'Vol_EGARCH'],
#       8     vol_col='Vol_EGARCH',
#
# File ~/Documents/Codes/Python/Thesis/src/regimes.py:114, in generate_expanding_hmm_targets(df, feature_cols, vol_col, n_components, min_window, refit_freq)
#     106 # 3. Fit Model
#     107 model = hmm.GaussianHMM(
#     108     n_components=n_components,
#     109     covariance_type="full",
#     110     n_iter=200,
#     111     random_state=42
#     112 )
# --> 114 model.fit(train_window_scaled)
#     116 # 4. Strict Convergence Check
#     117 if model.monitor_.converged:
#     118     # Map the states based on actual volatility
#
# File ~/Documents/Codes/Python/Thesis/.venv/lib/python3.12/site-packages/hmmlearn/base.py:480, in _AbstractHMM.fit(self, X, lengths)
#     477 if lengths is None:
#     478     lengths = np.asarray([X.shape[0]])
# --> 480 self._init(X, lengths)
#     481 self._check()
#     482 self.monitor_._reset()
#
# File ~/Documents/Codes/Python/Thesis/.venv/lib/python3.12/site-packages/hmmlearn/hmm.py:314, in GaussianHMM._init(self, X, lengths)
#     310 if self._needs_init("m", "means_"):
#     311     kmeans = cluster.KMeans(n_clusters=self.n_components,
#     312                             random_state=self.random_state,
#     313                             n_init=10)  # sklearn <1.4 backcompat.
# --> 314     kmeans.fit(X)
#     315     self.means_ = kmeans.cluster_centers_
#     316 if self._needs_init("c", "covars_"):
#
# File ~/Documents/Codes/Python/Thesis/.venv/lib/python3.12/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/Codes/Python/Thesis/.venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1516, in KMeans.fit(self, X, y, sample_weight)
#    1513     print("Initialization complete")
#    1515 # run a k-means once
# -> 1516 labels, inertia, centers, n_iter_ = kmeans_single(
#    1517     X,
#    1518     sample_weight,
#    1519     centers_init,
#    1520     max_iter=self.max_iter,
#    1521     verbose=self.verbose,
#    1522     tol=self._tol,
#    1523     n_threads=self._n_threads,
#    1524 )
#    1526 # determine if these results are the best so far
#    1527 # we chose a new run if it has a better inertia and the clustering is
#    1528 # different from the best so far (it's possible that the inertia is
#    1529 # slightly better even if the clustering is the same with potentially
#    1530 # permuted labels, due to rounding errors)
#    1531 if best_inertia is None or (
#    1532     inertia < best_inertia
#    1533     and not _is_same_clustering(labels, best_labels, self.n_clusters)
#    1534 ):
#
# File ~/Documents/Codes/Python/Thesis/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:210, in _threadpool_controller_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 controller = _get_threadpool_controller()
#     209 with controller.limit(limits=limits, user_api=user_api):
# --> 210     return func(*args, **kwargs)
#
# File ~/Documents/Codes/Python/Thesis/.venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:706, in _kmeans_single_lloyd(X, sample_weight, centers_init, max_iter, verbose, tol, n_threads)
#     703 strict_convergence = False
#     705 for i in range(max_iter):
# --> 706     lloyd_iter(
#     707         X,
#     708         sample_weight,
#     709         centers,
#     710         centers_new,
#     711         weight_in_clusters,
#     712         labels,
#     713         center_shift,
#     714         n_threads,
#     715     )
#     717     if verbose:
#     718         inertia = _inertia(X, sample_weight, centers, labels, n_threads)
#
# File sklearn/cluster/_k_means_lloyd.pyx:160, in sklearn.cluster._k_means_lloyd.lloyd_iter_chunked_dense()
# --> 160 'Could not get source, probably due dynamically evaluated source code.'
#
# File sklearn/cluster/_k_means_common.pyx:177, in sklearn.cluster._k_means_common._relocate_empty_clusters_dense()
# --> 177 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Documents/Codes/Python/Thesis/.venv/lib/python3.12/site-packages/numpy/_core/multiarray.py:403, in where(condition, x, y)
#     311     """
#     312     inner(a, b, /)
#     313
#    (...)    398
#     399     """
#     400     return (a, b)
# --> 403 @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
#     404 def where(condition, x=None, y=None, /):
#     405     """
#     406     where(condition, [x, y], /)
#     407
#    (...)    474            [ 0,  3, -1]])
#     475     """
#     476     return (condition, x, y)
#
# KeyboardInterrupt:
